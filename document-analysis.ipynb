# %% [markdown]
# # *Document Processing and Visualisation using spaCy*

# %%
import os
import numpy as np
import pandas as pd

import spacy
from spacy import displacy

import torch
import torch.nn as nn
import torch.nn.functional as tfunc

import matplotlib.pyplot as plt

# %% [markdown]
# <hr style="height:2px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# ## Taking a document and dividing into sentences

# %%
text_path='/kaggle/input/bbc-full-text-document-classification/bbc/tech/001.txt'
with open(text_path,'r',encoding='utf-8') as f:
    text=f.read()

nlp=spacy.load('en_core_web_sm')
doc=nlp(text)

for sent in doc.sents:
    print(sent.text)
# Out:
# Ink helps drive democracy in Asia
#
# The Kyrgyz Republic, a small, mountainous state of the former Soviet republic, is using invisible ink and ultraviolet readers in the country's elections as part of a drive to prevent multiple voting.
#
#
# This new technology is causing both worries and guarded optimism among different sectors of the population.
# In an effort to live up to its reputation in the 1990s as "an island of democracy", the Kyrgyz President, Askar Akaev, pushed through the law requiring the use of ink during the upcoming Parliamentary and Presidential elections.
# The US government agreed to fund all expenses associated with this decision.
#
#
# The Kyrgyz Republic is seen by many experts as backsliding from the high point it reached in the mid-1990s with a hastily pushed through referendum in 2003, reducing the legislative branch to one chamber with 75 deputies.
# The use of ink is only one part of a general effort to show commitment towards more open elections - the German Embassy, the Soros Foundation and the Kyrgyz government have all contributed to purchase transparent ballot boxes.
#
#
# The actual technology behind the ink is not that complicated.
# The ink is sprayed on a person's left thumb.
# It dries and is not visible under normal light.
#
#
# However, the presence of ultraviolet light (of the kind used to verify money) causes the ink to glow with a neon yellow light.
# At the entrance to each polling station, one election official will scan voter's fingers with UV lamp before allowing them to enter, and every voter will have his/her left thumb sprayed with ink before receiving the ballot.
# If the ink shows under the UV light the voter will not be allowed to enter the polling station.
# Likewise, any voter who refuses to be inked will not receive the ballot.
# These elections are assuming even greater significance because of two large factors - the upcoming parliamentary elections are a prelude to a potentially regime changing presidential election in the Autumn as well as the echo of recent elections in other former Soviet Republics, notably Ukraine and Georgia.
# The use of ink has been controversial - especially among groups perceived to be pro-government.
#
#
# Widely circulated articles compared the use of ink to the rural practice of marking sheep - a still common metaphor in this primarily agricultural society.
#
#
# The author of one such article began a petition drive against the use of the ink.
# The greatest part of the opposition to ink has often been sheer ignorance.
# Local newspapers have carried stories that the ink is harmful, radioactive or even that the ultraviolet readers may cause health problems.
# Others, such as the aggressively middle of the road, Coalition of Non-governmental Organizations, have lauded the move as an important step forward.
# This type of ink has been used in many elections in the world, in countries as varied as Serbia, South Africa, Indonesia and Turkey.
# The other common type of ink in elections is indelible visible ink - but as the elections in Afghanistan showed, improper use of this type of ink can cause additional problems.
# The use of "invisible" ink is not without its own problems.
# In most elections, numerous rumors have spread about it.
#
#
# In Serbia, for example, both Christian and Islamic leaders assured their populations that its use was not contrary to religion.
# Other rumours are associated with how to remove the ink - various soft drinks, solvents and cleaning products are put forward.
# However, in reality, the ink is very effective at getting under the cuticle of the thumb and difficult to wash off.
# The ink stays on the finger for at least 72 hours and for up to a week.
# The use of ink and readers by itself is not a panacea for election ills.
# The passage of the inking law is, nevertheless, a clear step forward towards free and fair elections."
# The country's widely watched parliamentary elections are scheduled for 27 February.
#
#
# David Mikosz works for the IFES, an international, non-profit organisation that supports the building of democratic societies.

# %%
doc[1].morph  #Morphology
# Out:
# Number=Sing|Person=3|Tense=Pres|VerbForm=Fin

# %% [markdown]
# # *Visualising Dependencies*

# %%
displacy.render(doc,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="367ac017980d40bbb557794cb7d4de07-0" class="displacy" width="119750" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ink</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">helps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">drive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">democracy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Asia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Kyrgyz</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Republic,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">small,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">mountainous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">state</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">former</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Soviet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">republic,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">invisible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">ink</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">ultraviolet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">readers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">country</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">elections</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="

# %% [markdown]
# # *Named Entitiy Visualisation*

# %%
displacy.render(doc,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ink helps drive democracy in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# <br><br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Kyrgyz Republic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , a small, mountainous state of the former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Soviet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  republic, is using invisible ink and ultraviolet readers in the country's elections as part of a drive to prevent multiple voting.<br><br>This new technology is causing both worries and guarded optimism among different sectors of the population. In an effort to live up to its reputation in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1990s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as &quot;an island of democracy&quot;, the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kyrgyz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  President,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Askar Akaev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , pushed through the law requiring the use of ink during the upcoming Parliamentary and Presidential elections. The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  government agreed to fund all expenses associated with this decision.<br><br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Kyrgyz Republic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is seen by many experts as backsliding from the high point it reached in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the mid-1990s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with a hastily pushed through referendum in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , reducing the legislative branch to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  chamber with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     75
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  deputies. The use of ink is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  part of a general effort to show commitment towards more open elections -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the German Embassy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Soros Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kyrgyz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government have all contributed to purchase transparent ballot boxes.<br><br>The actual technology behind the ink is not that complicated. The ink is sprayed on a person's left thumb. It dries and is not visible under normal light.<br><br>However, the presence of ultraviolet light (of the kind used to verify money) causes the ink to glow with a neon yellow light. At the entrance to each polling station,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  election official will
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     scan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  voter's fingers with UV lamp before allowing them to enter, and every voter will have his/her left thumb sprayed with ink before receiving the ballot. If the ink shows under the UV light the voter will not be allowed to enter the polling station. Likewise, any voter who refuses to be inked will not receive the ballot. These elections are assuming even greater significance because of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  large factors - the upcoming parliamentary elections are a prelude to a potentially regime changing presidential election in the Autumn as well as the echo of recent elections in other former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Soviet
#     <span style="font-size: 0.8em; font-weight: bold; line-height

# %% [markdown]
# <hr style="height:8px;border:none;color:#333;background-color:#333;" />

# %%
for token in doc:
    print(token.text,token.lemma_,token.pos_,sep=" | ")
# Out:
# Ink | ink | NOUN
# helps | helps | AUX
# drive | drive | VERB
# democracy | democracy | NOUN
# in | in | ADP
# Asia | Asia | PROPN
#
#
#  |
#
#  | SPACE
# The | the | DET
# Kyrgyz | Kyrgyz | PROPN
# Republic | Republic | PROPN
# , | , | PUNCT
# a | a | DET
# small | small | ADJ
# , | , | PUNCT
# mountainous | mountainous | ADJ
# state | state | NOUN
# of | of | ADP
# the | the | DET
# former | former | ADJ
# Soviet | soviet | ADJ
# republic | republic | NOUN
# , | , | PUNCT
# is | be | AUX
# using | use | VERB
# invisible | invisible | ADJ
# ink | ink | NOUN
# and | and | CCONJ
# ultraviolet | ultraviolet | NOUN
# readers | reader | NOUN
# in | in | ADP
# the | the | DET
# country | country | NOUN
# 's | 's | PART
# elections | election | NOUN
# as | as | ADP
# part | part | NOUN
# of | of | ADP
# a | a | DET
# drive | drive | NOUN
# to | to | PART
# prevent | prevent | VERB
# multiple | multiple | ADJ
# voting | voting | NOUN
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# This | this | DET
# new | new | ADJ
# technology | technology | NOUN
# is | be | AUX
# causing | cause | VERB
# both | both | DET
# worries | worry | NOUN
# and | and | CCONJ
# guarded | guard | VERB
# optimism | optimism | NOUN
# among | among | ADP
# different | different | ADJ
# sectors | sector | NOUN
# of | of | ADP
# the | the | DET
# population | population | NOUN
# . | . | PUNCT
# In | in | ADP
# an | an | DET
# effort | effort | NOUN
# to | to | PART
# live | live | VERB
# up | up | ADP
# to | to | ADP
# its | its | PRON
# reputation | reputation | NOUN
# in | in | ADP
# the | the | DET
# 1990s | 1990 | NOUN
# as | as | ADP
# " | " | PUNCT
# an | an | DET
# island | island | NOUN
# of | of | ADP
# democracy | democracy | NOUN
# " | " | PUNCT
# , | , | PUNCT
# the | the | DET
# Kyrgyz | Kyrgyz | PROPN
# President | President | PROPN
# , | , | PUNCT
# Askar | Askar | PROPN
# Akaev | Akaev | PROPN
# , | , | PUNCT
# pushed | push | VERB
# through | through | ADP
# the | the | DET
# law | law | NOUN
# requiring | require | VERB
# the | the | DET
# use | use | NOUN
# of | of | ADP
# ink | ink | NOUN
# during | during | ADP
# the | the | DET
# upcoming | upcoming | ADJ
# Parliamentary | parliamentary | ADJ
# and | and | CCONJ
# Presidential | presidential | ADJ
# elections | election | NOUN
# . | . | PUNCT
# The | the | DET
# US | US | PROPN
# government | government | NOUN
# agreed | agree | VERB
# to | to | PART
# fund | fund | VERB
# all | all | DET
# expenses | expense | NOUN
# associated | associate | VERB
# with | with | ADP
# this | this | DET
# decision | decision | NOUN
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# The | the | DET
# Kyrgyz | Kyrgyz | PROPN
# Republic | Republic | PROPN
# is | be | AUX
# seen | see | VERB
# by | by | ADP
# many | many | ADJ
# experts | expert | NOUN
# as | as | ADP
# backsliding | backslide | VERB
# from | from | ADP
# the | the | DET
# high | high | ADJ
# point | point | NOUN
# it | it | PRON
# reached | reach | VERB
# in | in | ADP
# the | the | DET
# mid-1990s | mid-1990 | NOUN
# with | with | ADP
# a | a | DET
# hastily | hastily | ADV
# pushed | push | VERB
# through | through | ADP
# referendum | referendum | NOUN
# in | in | ADP
# 2003 | 2003 | NUM
# , | , | PUNCT
# reducing | reduce | VERB
# the | the | DET
# legislative | legislative | ADJ
# branch | branch | NOUN
# to | to | ADP
# one | one | NUM
# chamber | chamber | NOUN
# with | with | ADP
# 75 | 75 | NUM
# deputies | deputy | NOUN
# . | . | PUNCT
# The | the | DET
# use | use | NOUN
# of | of | ADP
# ink | ink | NOUN
# is | be | AUX
# only | only | ADV
# one | one | NUM
# part | part | NOUN
# of | of | ADP
# a | a | DET
# general | general | ADJ
# effort | effort | NOUN
# to | to | PART
# show | show | VERB
# commitment | commitment | NOUN
# towards | towards | ADP
# more | more | ADV
# open | open | ADJ
# elections | election | NOUN
# - | - | PUNCT
# the | the | DET
# German | German | PROPN
# Embassy | Embassy | PROPN
# , | , | PUNCT
# the | the | DET
# Soros | Soros | PROPN
# Foundation | Foundation | PROPN
# and | and | CCONJ
# the | the | DET
# Kyrgyz | Kyrgyz | PROPN
# government | government | NOUN
# have | have | AUX
# all | all | ADV
# contributed | contribute | VERB
# to | to | PART
# purchase | purchase | VERB
# transparent | transparent | ADJ
# ballot | ballot | NOUN
# boxes | box | NOUN
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# The | the | DET
# actual | actual | ADJ
# technology | technology | NOUN
# behind | behind | ADP
# the | the | DET
# ink | ink | NOUN
# is | be | AUX
# not | not | PART
# that | that | ADV
# complicated | complicated | ADJ
# . | . | PUNCT
# The | the | DET
# ink | ink | NOUN
# is | be | AUX
# sprayed | spray | VERB
# on | on | ADP
# a | a | DET
# person | person | NOUN
# 's | 's | PART
# left | left | ADJ
# thumb | thumb | NOUN
# . | . | PUNCT
# It | it | PRON
# dries | dry | VERB
# and | and | CCONJ
# is | be | AUX
# not | not | PART
# visible | visible | ADJ
# under | under | ADP
# normal | normal | ADJ
# light | light | NOUN
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# However | however | ADV
# , | , | PUNCT
# the | the | DET
# presence | presence | NOUN
# of | of | ADP
# ultraviolet | ultraviolet | ADJ
# light | light | NOUN
# ( | ( | PUNCT
# of | of | ADP
# the | the | DET
# kind | kind | NOUN
# used | use | VERB
# to | to | PART
# verify | verify | VERB
# money | money | NOUN
# ) | ) | PUNCT
# causes | cause | VERB
# the | the | DET
# ink | ink | NOUN
# to | to | PART
# glow | glow | VERB
# with | with | ADP
# a | a | DET
# neon | neon | NOUN
# yellow | yellow | ADJ
# light | light | NOUN
# . | . | PUNCT
# At | at | ADP
# the | the | DET
# entrance | entrance | NOUN
# to | to | ADP
# each | each | DET
# polling | polling | NOUN
# station | station | NOUN
# , | , | PUNCT
# one | one | NUM
# election | election | NOUN
# official | official | NOUN
# will | will | AUX
# scan | scan | VERB
# voter | voter | PROPN
# 's | 's | PART
# fingers | finger | NOUN
# with | with | ADP
# UV | UV | PROPN
# lamp | lamp | NOUN
# before | before | ADP
# allowing | allow | VERB
# them | they | PRON
# to | to | PART
# enter | enter | VERB
# , | , | PUNCT
# and | and | CCONJ
# every | every | DET
# voter | voter | NOUN
# will | will | AUX
# have | have | VERB
# his | his | PRON
# / | / | SYM
# her | her | PRON
# left | left | ADJ
# thumb | thumb | NOUN
# sprayed | spray | VERB
# with | with | ADP
# ink | ink | NOUN
# before | before | ADP
# receiving | receive | VERB
# the | the | DET
# ballot | ballot | NOUN
# . | . | PUNCT
# If | if | SCONJ
# the | the | DET
# ink | ink | NOUN
# shows | show | VERB
# under | under | ADP
# the | the | DET
# UV | uv | NOUN
# light | light | NOUN
# the | the | DET
# voter | voter | NOUN
# will | will | AUX
# not | not | PART
# be | be | AUX
# allowed | allow | VERB
# to | to | PART
# enter | enter | VERB
# the | the | DET
# polling | polling | NOUN
# station | station | NOUN
# . | . | PUNCT
# Likewise | likewise | ADV
# , | , | PUNCT
# any | any | DET
# voter | voter | NOUN
# who | who | PRON
# refuses | refuse | VERB
# to | to | PART
# be | be | AUX
# inked | ink | VERB
# will | will | AUX
# not | not | PART
# receive | receive | VERB
# the | the | DET
# ballot | ballot | NOUN
# . | . | PUNCT
# These | these | DET
# elections | election | NOUN
# are | be | AUX
# assuming | assume | VERB
# even | even | ADV
# greater | great | ADJ
# significance | significance | NOUN
# because | because | SCONJ
# of | of | ADP
# two | two | NUM
# large | large | ADJ
# factors | factor | NOUN
# - | - | PUNCT
# the | the | DET
# upcoming | upcoming | ADJ
# parliamentary | parliamentary | ADJ
# elections | election | NOUN
# are | be | AUX
# a | a | DET
# prelude | prelude | NOUN
# to | to | ADP
# a | a | DET
# potentially | potentially | ADV
# regime | regime | NOUN
# changing | change | VERB
# presidential | presidential | ADJ
# election | election | NOUN
# in | in | ADP
# the | the | DET
# Autumn | Autumn | PROPN
# as | as | ADV
# well | well | ADV
# as | as | ADP
# the | the | DET
# echo | echo | NOUN
# of | of | ADP
# recent | recent | ADJ
# elections | election | NOUN
# in | in | ADP
# other | other | ADJ
# former | former | ADJ
# Soviet | Soviet | PROPN
# Republics | Republics | PROPN
# , | , | PUNCT
# notably | notably | ADV
# Ukraine | Ukraine | PROPN
# and | and | CCONJ
# Georgia | Georgia | PROPN
# . | . | PUNCT
# The | the | DET
# use | use | NOUN
# of | of | ADP
# ink | ink | NOUN
# has | have | AUX
# been | be | AUX
# controversial | controversial | ADJ
# - | - | PUNCT
# especially | especially | ADV
# among | among | ADP
# groups | group | NOUN
# perceived | perceive | VERB
# to | to | PART
# be | be | AUX
# pro | pro | ADJ
# - | - | ADJ
# government | government | ADJ
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# Widely | widely | ADV
# circulated | circulate | VERB
# articles | article | NOUN
# compared | compare | VERB
# the | the | DET
# use | use | NOUN
# of | of | ADP
# ink | ink | NOUN
# to | to | ADP
# the | the | DET
# rural | rural | ADJ
# practice | practice | NOUN
# of | of | ADP
# marking | mark | VERB
# sheep | sheep | NOUN
# - | - | PUNCT
# a | a | DET
# still | still | ADV
# common | common | ADJ
# metaphor | metaphor | NOUN
# in | in | ADP
# this | this | DET
# primarily | primarily | ADV
# agricultural | agricultural | ADJ
# society | society | NOUN
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# The | the | DET
# author | author | NOUN
# of | of | ADP
# one | one | NUM
# such | such | ADJ
# article | article | NOUN
# began | begin | VERB
# a | a | DET
# petition | petition | NOUN
# drive | drive | NOUN
# against | against | ADP
# the | the | DET
# use | use | NOUN
# of | of | ADP
# the | the | DET
# ink | ink | NOUN
# . | . | PUNCT
# The | the | DET
# greatest | great | ADJ
# part | part | NOUN
# of | of | ADP
# the | the | DET
# opposition | opposition | NOUN
# to | to | ADP
# ink | ink | NOUN
# has | have | AUX
# often | often | ADV
# been | be | AUX
# sheer | sheer | ADJ
# ignorance | ignorance | NOUN
# . | . | PUNCT
# Local | local | ADJ
# newspapers | newspaper | NOUN
# have | have | AUX
# carried | carry | VERB
# stories | story | NOUN
# that | that | SCONJ
# the | the | DET
# ink | ink | NOUN
# is | be | AUX
# harmful | harmful | ADJ
# , | , | PUNCT
# radioactive | radioactive | ADJ
# or | or | CCONJ
# even | even | ADV
# that | that | SCONJ
# the | the | DET
# ultraviolet | ultraviolet | NOUN
# readers | reader | NOUN
# may | may | AUX
# cause | cause | VERB
# health | health | NOUN
# problems | problem | NOUN
# . | . | PUNCT
# Others | other | NOUN
# , | , | PUNCT
# such | such | ADJ
# as | as | ADP
# the | the | DET
# aggressively | aggressively | ADV
# middle | middle | NOUN
# of | of | ADP
# the | the | DET
# road | road | NOUN
# , | , | PUNCT
# Coalition | Coalition | PROPN
# of | of | ADP
# Non | non | ADJ
# - | - | ADJ
# governmental | governmental | ADJ
# Organizations | Organizations | PROPN
# , | , | PUNCT
# have | have | AUX
# lauded | laud | VERB
# the | the | DET
# move | move | NOUN
# as | as | ADP
# an | an | DET
# important | important | ADJ
# step | step | NOUN
# forward | forward | ADV
# . | . | PUNCT
# This | this | DET
# type | type | NOUN
# of | of | ADP
# ink | ink | NOUN
# has | have | AUX
# been | be | AUX
# used | use | VERB
# in | in | ADP
# many | many | ADJ
# elections | election | NOUN
# in | in | ADP
# the | the | DET
# world | world | NOUN
# , | , | PUNCT
# in | in | ADP
# countries | country | NOUN
# as | as | ADV
# varied | varied | ADJ
# as | as | ADP
# Serbia | Serbia | PROPN
# , | , | PUNCT
# South | South | PROPN
# Africa | Africa | PROPN
# , | , | PUNCT
# Indonesia | Indonesia | PROPN
# and | and | CCONJ
# Turkey | Turkey | PROPN
# . | . | PUNCT
# The | the | DET
# other | other | ADJ
# common | common | ADJ
# type | type | NOUN
# of | of | ADP
# ink | ink | NOUN
# in | in | ADP
# elections | election | NOUN
# is | be | AUX
# indelible | indelible | ADJ
# visible | visible | ADJ
# ink | ink | NOUN
# - | - | PUNCT
# but | but | CCONJ
# as | as | SCONJ
# the | the | DET
# elections | election | NOUN
# in | in | ADP
# Afghanistan | Afghanistan | PROPN
# showed | show | VERB
# , | , | PUNCT
# improper | improper | ADJ
# use | use | NOUN
# of | of | ADP
# this | this | DET
# type | type | NOUN
# of | of | ADP
# ink | ink | NOUN
# can | can | AUX
# cause | cause | VERB
# additional | additional | ADJ
# problems | problem | NOUN
# . | . | PUNCT
# The | the | DET
# use | use | NOUN
# of | of | ADP
# " | " | PUNCT
# invisible | invisible | ADJ
# " | " | PUNCT
# ink | ink | NOUN
# is | be | AUX
# not | not | PART
# without | without | ADP
# its | its | PRON
# own | own | ADJ
# problems | problem | NOUN
# . | . | PUNCT
# In | in | ADP
# most | most | ADJ
# elections | election | NOUN
# , | , | PUNCT
# numerous | numerous | ADJ
# rumors | rumor | NOUN
# have | have | AUX
# spread | spread | VERB
# about | about | ADP
# it | it | PRON
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# In | in | ADP
# Serbia | Serbia | PROPN
# , | , | PUNCT
# for | for | ADP
# example | example | NOUN
# , | , | PUNCT
# both | both | CCONJ
# Christian | Christian | PROPN
# and | and | CCONJ
# Islamic | islamic | ADJ
# leaders | leader | NOUN
# assured | assure | VERB
# their | their | PRON
# populations | population | NOUN
# that | that | SCONJ
# its | its | PRON
# use | use | NOUN
# was | be | AUX
# not | not | PART
# contrary | contrary | ADJ
# to | to | ADP
# religion | religion | NOUN
# . | . | PUNCT
# Other | other | ADJ
# rumours | rumour | NOUN
# are | be | AUX
# associated | associate | VERB
# with | with | ADP
# how | how | SCONJ
# to | to | PART
# remove | remove | VERB
# the | the | DET
# ink | ink | NOUN
# - | - | PUNCT
# various | various | ADJ
# soft | soft | ADJ
# drinks | drink | NOUN
# , | , | PUNCT
# solvents | solvent | NOUN
# and | and | CCONJ
# cleaning | cleaning | NOUN
# products | product | NOUN
# are | be | AUX
# put | put | VERB
# forward | forward | ADV
# . | . | PUNCT
# However | however | ADV
# , | , | PUNCT
# in | in | ADP
# reality | reality | NOUN
# , | , | PUNCT
# the | the | DET
# ink | ink | NOUN
# is | be | AUX
# very | very | ADV
# effective | effective | ADJ
# at | at | ADP
# getting | get | VERB
# under | under | ADP
# the | the | DET
# cuticle | cuticle | NOUN
# of | of | ADP
# the | the | DET
# thumb | thumb | NOUN
# and | and | CCONJ
# difficult | difficult | ADJ
# to | to | PART
# wash | wash | VERB
# off | off | ADP
# . | . | PUNCT
# The | the | DET
# ink | ink | NOUN
# stays | stay | VERB
# on | on | ADP
# the | the | DET
# finger | finger | NOUN
# for | for | ADP
# at | at | ADV
# least | least | ADV
# 72 | 72 | NUM
# hours | hour | NOUN
# and | and | CCONJ
# for | for | ADP
# up | up | ADP
# to | to | PART
# a | a | DET
# week | week | NOUN
# . | . | PUNCT
# The | the | DET
# use | use | NOUN
# of | of | ADP
# ink | ink | NOUN
# and | and | CCONJ
# readers | reader | NOUN
# by | by | ADP
# itself | itself | PRON
# is | be | AUX
# not | not | PART
# a | a | DET
# panacea | panacea | NOUN
# for | for | ADP
# election | election | NOUN
# ills | ill | NOUN
# . | . | PUNCT
# The | the | DET
# passage | passage | NOUN
# of | of | ADP
# the | the | DET
# inking | inking | NOUN
# law | law | NOUN
# is | be | AUX
# , | , | PUNCT
# nevertheless | nevertheless | ADV
# , | , | PUNCT
# a | a | DET
# clear | clear | ADJ
# step | step | NOUN
# forward | forward | ADV
# towards | towards | ADP
# free | free | ADJ
# and | and | CCONJ
# fair | fair | ADJ
# elections | election | NOUN
# . | . | PUNCT
# " | " | PUNCT
# The | the | DET
# country | country | NOUN
# 's | 's | PART
# widely | widely | ADV
# watched | watch | VERB
# parliamentary | parliamentary | ADJ
# elections | election | NOUN
# are | be | AUX
# scheduled | schedule | VERB
# for | for | ADP
# 27 | 27 | NUM
# February | February | PROPN
# . | . | PUNCT
#
#
#  |
#
#  | SPACE
# David | David | PROPN
# Mikosz | Mikosz | PROPN
# works | work | VERB
# for | for | ADP
# the | the | DET
# IFES | IFES | PROPN
# , | , | PUNCT
# an | an | DET
# international | international | ADJ
# , | , | PUNCT
# non | non | ADJ
# - | - | ADJ
# profit | profit | ADJ
# organisation | organisation | NOUN
# that | that | PRON
# supports | support | VERB
# the | the | DET
# building | building | NOUN
# of | of | ADP
# democratic | democratic | ADJ
# societies | society | NOUN
# . | . | PUNCT
#
#  |
#  | SPACE

# %%
words=[token.text for token in doc]
vectors=[token.vector for token in doc]

from sklearn.decomposition import PCA

pca=PCA(n_components=2)
reduced_vectors=pca.fit_transform(vectors)

"""
plt.figure(figsize=(8,6))
for word,coord in zip(words,reduced_vectors):
    x,y=coord
    plt.scatter(x,y)
    plt.text(x+0.01,y+0.01,word,fontsize=12)

plt.title('Word Vector Visualisation')
plt.show()
"""
# Out:
# "\nplt.figure(figsize=(8,6))\nfor word,coord in zip(words,reduced_vectors):\n    x,y=coord\n    plt.scatter(x,y)\n    plt.text(x+0.01,y+0.01,word,fontsize=12)\n\nplt.title('Word Vector Visualisation')\nplt.show()\n"

# %% [markdown]
# <hr style="height:8px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# # *Word Vector Space Graph Visualisation using(t-distributed stochastic neighbour embedding)*

# %%
from sklearn.manifold import TSNE

vectors = np.array(vectors) 
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
reduced_vectors = tsne.fit_transform(vectors)

# %%
import plotly.express as px
df=pd.DataFrame(reduced_vectors,columns=['x','y'])
df['word']=words
fig=px.scatter(df,x='x',y='y',hover_data=['word'],title='Word Vectors')
fig.update_traces(marker=dict(size=10,opacity=0.8))
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f34e9e3b-b554-4cc0-8b20-169ba53eb7dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f34e9e3b-b554-4cc0-8b20-169ba53eb7dd")) {                    Plotly.newPlot(                        "f34e9e3b-b554-4cc0-8b20-169ba53eb7dd",                        [{"customdata":[["Ink"],["helps"],["drive"],["democracy"],["in"],["Asia"],["\n\n"],["The"],["Kyrgyz"],["Republic"],[","],["a"],["small"],[","],["mountainous"],["state"],["of"],["the"],["former"],["Soviet"],["republic"],[","],["is"],["using"],["invisible"],["ink"],["and"],["ultraviolet"],["readers"],["in"],["the"],["country"],["'s"],["elections"],["as"],["part"],["of"],["a"],["drive"],["to"],["prevent"],["multiple"],["voting"],["."],["\n\n"],["This"],["new"],["technology"],["is"],["causing"],["both"],["worries"],["and"],["guarded"],["optimism"],["among"],["different"],["sectors"],["of"],["the"],["population"],["."],["In"],["an"],["effort"],["to"],["live"],["up"],["to"],["its"],["reputation"],["in"],["the"],["1990s"],["as"],["\""],["an"],["island"],["of"],["democracy"],["\""],[","],["the"],["Kyrgyz"],["President"],[","],["Askar"],["Akaev"],[","],["pushed"],["through"],["the"],["law"],["requiring"],["the"],["use"],["of"],["ink"],["during"],["the"],["upcoming"],["Parliamentary"],["and"],["Presidential"],["elections"],["."],["The"],["US"],["government"],["agreed"],["to"],["fund"],["all"],["expenses"],["associated"],["with"],["this"],["decision"],["."],["\n\n"],["The"],["Kyrgyz"],["Republic"],["is"],["seen"],["by"],["many"],["experts"],["as"],["backsliding"],["from"],["the"],["high"],["point"],["it"],["reached"],["in"],["the"],["mid-1990s"],["with"],["a"],["hastily"],["pushed"],["through"],["referendum"],["in"],["2003"],[","],["reducing"],["the"],["legislative"],["branch"],["to"],["one"],["chamber"],["with"],["75"],["deputies"],["."],["The"],["use"],["of"],["ink"],["is"],["only"],["one"],["part"],["of"],["a"],["general"],["effort"],["to"],["show"],["commitment"],["towards"],["more"],["open"],["elections"],["-"],["the"],["German"],["Embassy"],[","],["the"],["Soros"],["Foundation"],["and"],["the"],["Kyrgyz"],["government"],["have"],["all"],["contributed"],["to"],["purchase"],["transparent"],["ballot"],["boxes"],["."],["\n\n"],["The"],["actual"],["technology"],["behind"],["the"],["ink"],["is"],["not"],["that"],["complicated"],["."],["The"],["ink"],["is"],["sprayed"],["on"],["a"],["person"],["'s"],["left"],["thumb"],["."],["It"],["dries"],["and"],["is"],["not"],["visible"],["under"],["normal"],["light"],["."],["\n\n"],["However"],[","],["the"],["presence"],["of"],["ultraviolet"],["light"],["("],["of"],["the"],["kind"],["used"],["to"],["verify"],["money"],[")"],["causes"],["the"],["ink"],["to"],["glow"],["with"],["a"],["neon"],["yellow"],["light"],["."],["At"],["the"],["entrance"],["to"],["each"],["polling"],["station"],[","],["one"],["election"],["official"],["will"],["scan"],["voter"],["'s"],["fingers"],["with"],["UV"],["lamp"],["before"],["allowing"],["them"],["to"],["enter"],[","],["and"],["every"],["voter"],["will"],["have"],["his"],["\u002f"],["her"],["left"],["thumb"],["sprayed"],["with"],["ink"],["before"],["receiving"],["the"],["ballot"],["."],["If"],["the"],["ink"],["shows"],["under"],["the"],["UV"],["light"],["the"],["voter"],["will"],["not"],["be"],["allowed"],["to"],["enter"],["the"],["polling"],["station"],["."],["Likewise"],[","],["any"],["voter"],["who"],["refuses"],["to"],["be"],["inked"],["will"],["not"],["receive"],["the"],["ballot"],["."],["These"],["elections"],["are"],["assuming"],["even"],["greater"],["significance"],["because"],["of"],["two"],["large"],["factors"],["-"],["the"],["upcoming"],["parliamentary"],["elections"],["are"],["a"],["prelude"],["to"],["a"],[ ...

# %% [markdown]
# <hr style="height:8px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# <div style="border: 2px solid #4CAF50; border-radius: 10px; padding: 15px; background-color: #F0FFF0; color: black;">
#   <h3> Dependency Parse Components</h3>
#
#   <ul>
#     <li><b>token.dep_</b> → dependency relation of that word</li>
#     <li><b>token.head.text</b> → the head word this token depends on</li>
#     <li><b>token.head.pos_</b> → the part-of-speech of the head word</li>
#     <li><b>token.children</b> → the list of tokens that depend on this token</li>
#   </ul>
# </div>

# %%
from IPython.display import HTML

#->In pandas tabular format

rows = []
for token in doc:
    rows.append({
        "Token": token.text,
        "Dep": token.dep_,
        "Head": token.head.text,
        "Head POS": token.head.pos_,
        "Children": ', '.join(child.text for child in token.children)
    })

df = pd.DataFrame(rows)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Token</th>
#       <th>Dep</th>
#       <th>Head</th>
#       <th>Head POS</th>
#       <th>Children</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Ink</td>
#       <td>nsubj</td>
#       <td>helps</td>
#       <td>AUX</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>helps</td>
#       <td>aux</td>
#       <td>using</td>
#       <td>VERB</td>
#       <td>Ink, drive, ,</td>
#     </tr>
#     <tr>
#       <td>drive</td>
#       <td>xcomp</td>
#       <td>helps</td>
#       <td>AUX</td>
#       <td>democracy, in</td>
#     </tr>
#     <tr>
#       <td>democracy</td>
#       <td>dobj</td>
#       <td>drive</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>in</td>
#       <td>prep</td>
#       <td>drive</td>
#       <td>VERB</td>
#       <td>Republic</td>
#     </tr>
#     <tr>
#       <td>Asia</td>
#       <td>compound</td>
#       <td>Republic</td>
#       <td>PROPN</td>
#       <td>\n\n</td>
#     </tr>
#     <tr>
#       <td>\n\n</td>
#       <td>dep</td>
#       <td>Asia</td>
#       <td>PROPN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>The</td>
#       <td>det</td>
#       <td>Republic</td>
#       <td>PROPN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Kyrgyz</td>
#       <td>compound</td>
#       <td>Republic</td>
#       <td>PROPN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Republic</td>
#       <td>pobj</td>
#       <td>in</td>
#       <td>ADP</td>
#       <td>Asia, The, Kyrgyz, ,, state</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>punct</td>
#       <td>Republic</td>
#       <td>PROPN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>det</td>
#       <td>state</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>small</td>
#       <td>amod</td>
#       <td>state</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>punct</td>
#       <td>state</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>mountainous</td>
#       <td>amod</td>
#       <td>state</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>state</td>
#       <td>appos</td>
#       <td>Republic</td>
#       <td>PROPN</td>
#       <td>a, small, ,, mountainous, of</td>
#     </tr>
#     <tr>
#       <td>of</td>
#       <td>prep</td>
#       <td>state</td>
#       <td>NOUN</td>
#       <td>republic</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>det</td>
#       <td>republic</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>former</td>
#       <td>amod</td>
#       <td>republic</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Soviet</td>
#       <td>amod</td>
#       <td>republic</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>republic</td>
#       <td>pobj</td>
#       <td>of</td>
#       <td>ADP</td>
#       <td>the, former, Soviet</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>punct</td>
#       <td>helps</td>
#       <td>AUX</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>is</td>
#       <td>aux</td>
#       <td>using</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>using</td>
#       <td>ROOT</td>
#       <td>using</td>
#       <td>VERB</td>
#       <td>helps, is, ink, as, .</td>
#     </tr>
#     <tr>
#       <td>invisible</td>
#       <td>amod</td>
#       <td>ink</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ink</td>
#       <td>dobj</td>
#       <td>using</td>
#       <td>VERB</td>
#       <td>invisible, and, readers, in</td>
#     </tr>
#     <tr>
#       <td>and</td>
#       <td>cc</td>
#       <td>ink</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ultraviolet</td>
#       <td>amod</td>
#       <td>readers</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>readers</td>
#       <td>conj</td>
#       <td>ink</td>
#       <td>NOUN</td>
#       <td>ultraviolet</td>
#     </tr>
#     <tr>
#       <td>in</td>
#       <td>prep</td>
#       <td>ink</td>
#       <td>NOUN</td>
#       <td>elections</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>det</td>
#       <td>country</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>country</td>
#       <td>poss</td>
#       <td>elections</td>
#       <td>NOUN</td>
#       <td>the, 's</td>
#     </tr>
#     <tr>
#       <td>'s</td>
#       <td>case</td>
#       <td>country</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>elections</td>
#       <td>pobj</td>
#       <td>in</td>
#       <td>ADP</td>
#       <td>country</td>
#     </tr>
#     <tr>
#       <td>as</td>
#       <td>prep</td>
#       <td>using</td>
#       <td>VERB</td>
#       <td>part</td>
#     </tr>
#     <tr>
#       <td>part</td>
#       <td>pobj</td>
#       <td>as</td>
#       <td>ADP</td>
#       <td>of</td>
#     </tr>
#     <tr>
#       <td>of</td>
#       <td>prep</td>
#       <td>part</td>
#       <td>NOUN</td>
#       <td>drive</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>det</td>
#       <td>drive</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>drive</td>
#       <td>pobj</td>
#       <td>of</td>
#       <td>ADP</td>
#       <td>a, prevent</td>
#     </tr>
#     <tr>
#       <td>to</td>
#       <td>aux</td>
#       <td>prevent</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>prevent</td>
#       <td>relcl</td>
#       <td>drive</td>
#       <td>NOUN</td>
#       <td>to, voting</td>
#     </tr>
#     <tr>
#       <td>multiple</td>
#       <td>amod</td>
#       <td>voting</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>voting</td>
#       <td>dobj</td>
#       <td>prevent</td>
#       <td>VERB</td>
#       <td>multiple</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>punct</td>
#       <td>using</td>
#       <td>VERB</td>
#       <td>\n\n</td>
#     </tr>
#     <tr>
#       <td>\n\n</td>
#       <td>dep</td>
#       <td>.</td>
#       <td>PUNCT</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>This</td>
#       <td>det</td>
#       <td>technology</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>new</td>
#       <td>amod</td>
#       <td>technology</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>technology</td>
#       <td>nsubj</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td>This, new</td>
#     </tr>
#     <tr>
#       <td>is</td>
#       <td>aux</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>causing</td>
#       <td>ROOT</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td>technology, is, worries, and, guarded, .</td>
#     </tr>
#     <tr>
#       <td>both</td>
#       <td>det</td>
#       <td>worries</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>worries</td>
#       <td>dobj</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td>both</td>
#     </tr>
#     <tr>
#       <td>and</td>
#       <td>cc</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>guarded</td>
#       <td>conj</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td>optimism, among</td>
#     </tr>
#     <tr>
#       <td>optimism</td>
#       <td>dobj</td>
#       <td>guarded</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>among</td>
#       <td>prep</td>
#       <td>guarded</td>
#       <td>VERB</td>
#       <td>sectors</td>
#     </tr>
#     <tr>
#       <td>different</td>
#       <td>amod</td>
#       <td>sectors</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>sectors</td>
#       <td>pobj</td>
#       <td>among</td>
#       <td>ADP</td>
#       <td>different, of</td>
#     </tr>
#     <tr>
#       <td>of</td>
#       <td>prep</td>
#       <td>sectors</td>
#       <td>NOUN</td>
#       <td>population</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>det</td>
#       <td>population</td>
#       <td>NOUN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>population</td>
#       <td>pobj</td>
#       <td>of</td>
#       <td>ADP</td>
#       <td>the</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>punct</td>
#       <td>causing</td>
#       <td>VERB</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>In</td>
#       <td>prep</td>
#       <td>pushed</td>
#       <td>VERB</td>
#       <td>effort</td>
#     </tr>
#     <tr>
#       <td>an</td>

# %% [markdown]
# <hr style="height:8px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# ## *A few tokens need to be retokenized in the corpus example.*

# %%
for i in range(0,len(doc)):
    if doc[i].text=="The Kyrgyz Republic":
        print(i)
#->Use entity ruler or phrase matcher        
#->token.i if iterating token over doc
print(doc[7:10])

with doc.retokenize() as retokenizer:
    attrs = {"LEMMA": "Kyrgyz Republic", "POS": "PROPN", "TAG": "NNP"}
    retokenizer.merge(doc[7:10], attrs=attrs)

print(doc[7])
# Out:
# The Kyrgyz Republic
# The Kyrgyz Republic
